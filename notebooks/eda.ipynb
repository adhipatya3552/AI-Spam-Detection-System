# %%
import pandas as pd

df = pd.read_csv("../data/raw/spam.csv", encoding='latin-1')

print(df.head())
print(df.shape)
print(df.info())

# %%
df = df[['v1', 'v2']]

df.columns = ['label', 'text']

print(df.head())

# %%
df['label'] = df['label'].map({
    'ham': 0,
    'spam': 1
})
